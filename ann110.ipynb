# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
# load the dataset
dataset = loadtxt('C:/Users/mdash/Desktop/SDSC/ACE_TEACHING/ToPOST/DAY3_POST/datasets_228_482_diabetes_nh.csv', delimiter=',')
print(dataset.shape)
# split into input (X) and output (y) variables
Xtr = dataset[:600,0:8]
ytr = dataset[:600,8]
Xtst = dataset[600:768,0:8]
ytst = dataset[600:768,8]
# Out:
# (768, 9)

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
#model.add(Dense(4, activation='relu'))
model.add(Dense(8, activation='relu'))
#model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(Xtr, ytr, epochs=600, batch_size=10, verbose=1)
#model.fit(Xtr, ytr, epochs=150, batch_size=10)
# evaluate the keras model
_, accuracy = model.evaluate(Xtst, ytst, verbose=0)
# _, accuracy = model.evaluate(Xtst, ytst)
print('Accuracy: %.2f ' % (accuracy*100))
# Out:
# Epoch 1/600
# 60/60 [==============================] - 1s 2ms/step - loss: 1.8309 - accuracy: 0.5200
# Epoch 2/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9961 - accuracy: 0.5800
# Epoch 3/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9003 - accuracy: 0.6200
# Epoch 4/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8154 - accuracy: 0.6000
# Epoch 5/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8086 - accuracy: 0.6067
# Epoch 6/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7675 - accuracy: 0.6133
# Epoch 7/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7472 - accuracy: 0.6150
# Epoch 8/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7379 - accuracy: 0.6133
# Epoch 9/600
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7248 - accuracy: 0.6417
# Epoch 10/600
# ...
